# %%
import os

from moexalgo import session

session.TOKEN = os.environ['APIKEY']
from moexalgo.next import Market

# %%
shares = Market('shares')
shares.tickers()
# Out:
#     ticker board   shortname  lotsize  decimals  minstep   issuesize  \
# 0     ABIO  TQBR  iАРТГЕН ао       10         2    0.020    92645451
# 1     ABRD  TQBR  АбрауДюрсо       10         1    0.200   108889117
# 2     AFKS  TQBR  Система ао      100         3    0.001  9650000000
# 3     AFLT  TQBR    Аэрофлот       10         2    0.010  3975771215
# 4     AKRN  TQBR       Акрон        1         0    2.000    36757156
# ..     ...   ...         ...      ...       ...      ...         ...
# 253   YRSB  TQBR     ТНСэнЯр       10         0    2.000    17143584
# 254  YRSBP  TQBR   ТНСэнЯр-п       10         1    0.500     4507320
# 255   ZAYM  TQBR   Займер ао       10         2    0.050   100000000
# 256   ZILL  TQBR      ЗИЛ ао        1         0    5.000     2659962
# 257   ZVEZ  TQBR   ЗВЕЗДА ао     1000         2    0.010   562020480
#
#              isin     regnumber  listlevel
# 0    RU000A0JNAB6  1-01-08902-A          2
# 1    RU000A0JS5T7  1-02-12500-A          3
# ...

# %%
bonds = Market('bonds')
bonds.tickers()
# Out:
#           ticker board  shortname  prevwaprice  yieldatprevwaprice  \
# 0   SU25085RMFS0  TQOB  ОФЗ 25085          NaN                0.00
# 1   SU26207RMFS9  TQOB  ОФЗ 26207       93.692               13.78
# 2   SU26212RMFS9  TQOB  ОФЗ 26212       87.400               14.00
# 3   SU26218RMFS6  TQOB  ОФЗ 26218       78.880               14.27
# 4   SU26219RMFS4  TQOB  ОФЗ 26219       94.828               14.01
# 5   SU26221RMFS0  TQOB  ОФЗ 26221       70.681               14.67
# 6   SU26224RMFS4  TQOB  ОФЗ 26224       80.919               14.15
# 7   SU26225RMFS1  TQOB  ОФЗ 26225       66.097               14.68
# 8   SU26226RMFS9  TQOB  ОФЗ 26226       94.837               13.88
# 9   SU26228RMFS5  TQOB  ОФЗ 26228       80.029               14.16
# 10  SU26229RMFS3  TQOB  ОФЗ 26229       98.828               15.48
# 11  SU26230RMFS1  TQOB  ОФЗ 26230       61.720               14.63
# 12  SU26231RMFS9  TQOB  ОФЗ 26231          NaN                0.00
# ...

# %%
index = Market('index')
index.tickers()
# Out:
#       ticker board                                               name  \
# 0      IMOEX  SNDX                                    Индекс МосБиржи
# 1     IMOEX2  SNDX  IMOEX2 – значения индекса МосБиржи за весь тор...
# 2     MECHTR  SNDX  Индекс МосБиржи химии и нефтехимии полной дохо...
# 3    MECHTRN  SNDX  Индекс МосБиржи химии и нефтехимии полной дохо...
# 4    MECHTRR  SNDX  Индекс МосБиржи химии и нефтехимии полной дохо...
# ..       ...   ...                                                ...
# 64   RUCBITR  SNDX            Индекс Мосбиржи корпоративных облигаций
# 65  RUCBTR3Y  SNDX   Индекс Мосбиржи корпоративных облигаций MOEX 1-3
# 66  RUCBTR5Y  SNDX        Индекс Мосбиржи корпоративных облигаций 3-5
# 67   RUMBICP  SNDX    Индекс Мосбиржи муниципальных облигаций ценовой
# 68   RUMBITR  SNDX            Индекс Мосбиржи муниципальных облигаций
#
#     decimals                           shortname  annualhigh  annuallow  \
# ...

# %%
currency = Market('currency')
currency.tickers()
# Out:
#            ticker board   shortname  lotsize  settledate  decimals  facevalue  \
# 0    AEDRUBTODTOM  CETS  AED_TODTOM   100000  2025-09-23         4          1
# 1      AEDRUB_SPT  CETS  AEDRUB_SPT     1000  2025-09-25         4          1
# 2      AEDRUB_TMS  CETS  AEDRUB_TMS        1  2025-09-24         4          1
# 3      AEDRUB_TOD  CETS  AEDRUB_TOD     1000  2025-09-23         4          1
# 4      AEDRUB_TOM  CETS  AEDRUB_TOM     1000  2025-09-24         4          1
# ..            ...   ...         ...      ...         ...       ...        ...
# 194    UZSRUB_TOM  CETS  UZSRUB_TOM  1000000  2025-09-24         4      10000
# 195  ZARRUBTODTOM  CETS  ZAR_TODTOM  1000000  2025-09-23         4         10
# 196    ZARRUB_TMS  CETS  ZARRUB_TMS        1  2025-09-24         4         10
# 197    ZARRUB_TOD  CETS  ZARRUB_TOD    10000  2025-09-23         4         10
# 198    ZARRUB_TOM  CETS  ZARRUB_TOM    10000  2025-09-24         4         10
#
# ...

# %%
futures = Market('futures')
futures.tickers()
# Out:
#     ticker board   shortname                         secname  prevsettleprice  \
# 0     AEH6  RFUD    AED-3.26    Фьючерсный контракт AED-3.26           24.277
# 1     AEM6  RFUD    AED-6.26    Фьючерсный контракт AED-6.26           24.449
# 2     AEZ5  RFUD   AED-12.25   Фьючерсный контракт AED-12.25           23.623
# 3     AFH6  RFUD   AFLT-3.26   Фьючерсный контракт AFLT-3.26         6306.000
# 4     AFZ5  RFUD  AFLT-12.25  Фьючерсный контракт AFLT-12.25         6083.000
# ..     ...   ...         ...                             ...              ...
# 391   XIZ5  RFUD   XIA-12.25   Фьючерсный контракт XIA-12.25           57.100
# 392   YDH6  RFUD   YDEX-3.26   Фьючерсный контракт YDEX-3.26         4385.000
# 393   YDZ5  RFUD  YDEX-12.25  Фьючерсный контракт YDEX-12.25         4211.000
# 394   ZCH6  RFUD   ZINC-3.26   Фьючерсный контракт ZINC-3.26         2940.500
# 395   ZCZ5  RFUD  ZINC-12.25  Фьючерсный контракт ZINC-12.25         2902.000
#
# ...

# %%
options = Market('options')
options.tickers()
# Out:
#           ticker board                shortname  \
# 0      AF4000BL5  ROPD  AFLT-12.25M171225CA4000
# 1      AF4000BX5  ROPD  AFLT-12.25M171225PA4000
# 2      AF4250BC6  ROPD   AFLT-3.26M180326CA4250
# 3      AF4250BL5  ROPD  AFLT-12.25M171225CA4250
# 4      AF4250BO6  ROPD   AFLT-3.26M180326PA4250
# ...          ...   ...                      ...
# 29303   YD900CR9  ROPD         YDEXP200629PE900
# 29304   YD900CU8  ROPD         YDEXP200928PE900
# 29305   YD900CU9  ROPD         YDEXP190929PE900
# 29306   YD900CX8  ROPD         YDEXP201228PE900
# 29307   YD900CX9  ROPD         YDEXP191229PE900
#
#                                                  secname  prevsettleprice  \
# 0      Марж. амер. Call 4000 с исп. 17 дек. на фьюч. ...          2098.00
# 1      Марж. амер. Put 4000 с исп. 17 дек. на фьюч. к...            15.00
# 2      Марж. амер. Call 4250 с исп. 18 марта на фьюч....          2102.00
# 3      Марж. амер. Call 4250 с исп. 17 дек. на фьюч. ...          1850.00
# ...
