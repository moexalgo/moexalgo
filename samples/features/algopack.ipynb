# %%
import os

import moexalgo
from moexalgo import session

session.TOKEN = os.environ['APIKEY']

# %%
eq = moexalgo.Market('EQ')
eq.tradestats(date='2024-01-05')
# Out:
#         tradedate tradetime ticker        pr_open        pr_high  \
# 0      2024-01-05  10:05:00   ABIO     109.560000     110.620000
# 1      2024-01-05  10:05:00   ABRD     269.600000     270.000000
# 2      2024-01-05  10:05:00   AFKS      16.426000      16.450000
# 3      2024-01-05  10:05:00   AFLT      35.590000      35.680000
# 4      2024-01-05  10:05:00   AGRO    1391.600000    1391.600000
# ...           ...       ...    ...            ...            ...
# 23163  2024-01-05  23:50:00  TRNFP  145500.000000  145550.000000
# 23164  2024-01-05  23:50:00   UPRO       2.053000       2.054000
# 23165  2024-01-05  23:50:00   VKCO     580.000000     580.800000
# 23166  2024-01-05  23:50:00   VTBR       0.023965       0.024055
# 23167  2024-01-05  23:50:00   YNDX    2576.600000    2576.800000
#
#               pr_low    pr_close  pr_std     vol       val  ...   vol_b  \
# 0         109.100000     109.940  0.0014    2064   2269358  ...    1082
# ...

# %%
moex = moexalgo.Ticker('MOEX')
moex.tradestats(start='2024-01-05', end='2024-01-05')
# Out:
#       tradedate tradetime ticker  pr_open  pr_high  pr_low  pr_close  pr_std  \
# 0    2024-01-05  10:05:00   MOEX   194.00   194.35  193.85    194.30  0.0003
# 1    2024-01-05  10:10:00   MOEX   194.31   194.42  194.30    194.40  0.0001
# 2    2024-01-05  10:15:00   MOEX   194.39   194.55  194.31    194.31  0.0001
# 3    2024-01-05  10:20:00   MOEX   194.31   194.32  194.09    194.09  0.0002
# 4    2024-01-05  10:25:00   MOEX   194.09   194.31  194.00    194.17  0.0002
# ..          ...       ...    ...      ...      ...     ...       ...     ...
# 156  2024-01-05  23:30:00   MOEX   193.08   193.08  193.05    193.08  0.0001
# 157  2024-01-05  23:35:00   MOEX   193.06   193.09  193.05    193.09  0.0001
# 158  2024-01-05  23:40:00   MOEX   193.08   193.08  193.05    193.06  0.0000
# 159  2024-01-05  23:45:00   MOEX   193.06   193.17  193.04    193.04  0.0001
# 160  2024-01-05  23:50:00   MOEX   193.03   193.27  193.03    193.08  0.0003
#
# ...
