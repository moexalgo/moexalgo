# %% [markdown]
# Настоятельно рекомендуем передавать APIKEY в код или в Jupiter notebook, через переменную окружения.

# %%
import os
from moexalgo import session
# session.TOKEN = 'Ваш APIKEY здесь'
session.TOKEN = os.environ['APIKEY']

# %%
from moexalgo import Market

eq = Market('EQ')
eq.tradestats(date='2024-10-03')
