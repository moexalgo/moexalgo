# %% [markdown]
# 1) Тикер VEON-RX. Если не передавать boardid, то срабатывает регулярка \W и название тикера пилится на составляющие – VEON, RX
# 5) справочник старых данных по контрактам (типо riz2)
# 6) futoi для одного тикера а не для всего маркета

# %%
from moexalgo import session, Market, Ticker, Futures
from datetime import date


VEON_RX = Ticker('VEON-RX')
VEON_RX.candles(start='2024-04-22', end='2024-04-22')
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/proj/MOEXAlgo/.v310/lib/python3.10/site-packages/httpx/_transports/default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File ~/proj/MOEXAlgo/.v310/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/proj/MOEXAlgo/.v310/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...

# %%
RIZ2 = Futures('RIZ2', 'RFUD')
RIZ2.tradestats(start='2022-08-02', end='2022-08-02')
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[2], line 2
#       1 RIZ2 = Futures('RIZ2', 'RFUD')
# ----> 2 RIZ2.tradestats(start='2022-08-02', end='2022-08-02')
#
# File ~/proj/MOEXAlgo/moexalgo/futures.py:159, in Futures.tradestats(self, start, end, latest, offset, cs, use_dataframe)
#     126 def tradestats(self,
#     127                *,
#     128                start: Union[str, date],
#    (...)
#     132                cs: Session = None,
#     133                use_dataframe: bool = True) -> Union[iter, pd.DataFrame]:
#     134     """
#     135     Возвращает метрики `TradeStat` (статистику по сделкам) по заданным параметрам.
#     136     Больше информации о метрике `TradeStat` можно найти на странице: https://moexalgo.github.io/des/supercandles/#tradestats_1
#    (...)
#     157         Итератор или `pd.DataFrame` метрик `TradeStat`.
#     158     """
# ...

# %%
AKM4 = Ticker('AKM4')
AKM4.futoi(start='2024-04-01',  end='2024-04-22')

# %%
AKM4.tradestats(start='2024-04-01',  end='2024-04-22')

# %%
RIZ2 = Ticker('RIZ2')
RIZ2.futoi(start='2022-08-02', end='2022-08-02')

# %%
MOEX = Ticker('MOEX')
MOEX.trades()

# %%
CNY000000TOD = Ticker('CNY000000TOD')
CNY000000TOD.trades()
# Out:
#         tradeno tradetime boardid         secid    price  quantity      value  \
# 0     679427369  10:00:01    CETS  CNY000000TOD  11.6770        50   583850.0
# 1     679427370  10:00:01    CETS  CNY000000TOD  11.6770       200  2335400.0
# 2     679427379  10:00:01    CETS  CNY000000TOD  11.6870       130  1519310.0
# 3     679427385  10:00:01    CETS  CNY000000TOD  11.6890       130  1519570.0
# 4     679427386  10:00:01    CETS  CNY000000TOD  11.6890        50   584450.0
# ...         ...       ...     ...           ...      ...       ...        ...
# 9995  679465208  11:17:15    CETS  CNY000000TOD  11.8095       100  1180950.0
# 9996  679465209  11:17:15    CETS  CNY000000TOD  11.8095        27   318856.5
# 9997  679465214  11:17:15    CETS  CNY000000TOD  11.8100       127  1499870.0
# 9998  679465215  11:17:15    CETS  CNY000000TOD  11.8100       100  1181000.0
# 9999  679465216  11:17:15    CETS  CNY000000TOD  11.8100       100  1181000.0
#
# ...

# %%
sber = Ticker('SBER') 
tr=sber.tradestats(start='2024-05-06', end="2024-05-06").head()
tr
# Out:
#   ticker   tradedate tradetime  pr_open  pr_high  pr_low  pr_close  pr_std  \
# 0   SBER  2024-05-06  10:05:00   308.08   308.09  307.50    307.73  0.0001
# 1   SBER  2024-05-06  10:10:00   307.74   307.74  307.38    307.62  0.0000
# 2   SBER  2024-05-06  10:15:00   307.66   307.66  307.51    307.52  0.0000
# 3   SBER  2024-05-06  10:20:00   307.53   307.53  307.27    307.29  0.0000
# 4   SBER  2024-05-06  10:25:00   307.29   307.48  307.26    307.41  0.0000
#
#      vol          val  ...  vol_b  vol_s  disb  pr_vwap_b  pr_vwap_s  \
# 0  55866  171913904.0  ...  18572  37294 -0.34     307.80     307.69
# 1  57347  176369351.0  ...  11451  45896 -0.60     307.56     307.55
# 2  25076   77127097.0  ...  12014  13062 -0.04     307.58     307.57
# 3  68296  209931697.0  ...   7075  61221 -0.79     307.36     307.39
# 4  11875   36497487.0  ...   7440   4435  0.25     307.33     307.38
#
#               systime  sec_pr_open  sec_pr_high  sec_pr_low  sec_pr_close
# ...
